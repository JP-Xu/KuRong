# %%
import pymongo
from pymongo import MongoClient
from datetime import date

client = pymongo.MongoClient("mongodb://127.0.0.1:27017")
db = client.JiFeng
con = db.ILthermo

# %%
con.count({})
# Out:
# /var/folders/wr/rqn0k_ts5kbg2vt8fxfs4yvw0000gn/T/ipykernel_11662/3616724838.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   con.count({})
# 45120

# %%
agg_result = con.aggregate([{'$match': {"property":"Density"}},
                           {"$group": {"SMILE": {"component 1":{"$SMILES"}}}}])
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 agg_result = con.aggregate([{'$match': {"property":"Density"}},
#       2                            {"$group": {"SMILE": {"component 1":{"$SMILES"}}}}])
#
# File /usr/local/Caskroom/miniconda/base/lib/python3.9/site-packages/pymongo/collection.py:2496, in Collection.aggregate(self, pipeline, session, **kwargs)
#    2423 """Perform an aggregation using the aggregation framework on this
#    2424 collection.
#    2425
#    (...)
#    2493     https://docs.mongodb.com/manual/reference/command/aggregate
#    2494 """
#    2495 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2496     return self._aggregate(_CollectionAggregationCommand,
#    2497                            pipeline,
#    2498                            CommandCursor,
# ...

# %%
for i in agg_result:
    print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %%
#agg_result = con.find({})

# %%
for i in con.find({"_id":100}):
    print(i)
# Out:
# {'_id': 100, 'ref': 'Liu et al. (2016e)', 'property': 'Composition at phase equilibrium', 'phase': 'Liquid mixture 1', 'datapoints': 'Liquid mixture 2', 'title': 'Phase Behavior of Aqueous Two-Phase Systems Composed by 1-Allyl-3-methylimidazolium Chloride and Aqueous Potassium Salts at Various Temperatures', 'reference': 'Liu, Q.; Ni, L.; Han, J.; Wang, Y.; Tang, X.; Zhang, W.; Xie, X. (2016) J. Chem. Eng. Data 61(10), 3698-3703.', 'component 1': {'Component': '1', 'Name': 'potassium citrate', 'Formula': 'C6H5K3O7', 'Mol weight': '306.39', 'SMILES': '[K]~C(C(=O)[O-])C(CC(=O)[O-])(C(=O)[O-])O', 'Structure': 'https://ilthermo.boulder.nist.gov/ILT2/ilimage?key=ABGvSs'}, 'component 2': {'Component': '2', 'Name': 'water', 'Formula': 'H2O', 'Mol weight': '18.02', 'SMILES': 'O', 'Structure': 'https://ilthermo.boulder.nist.gov/ILT2/ilimage?key=AADYxI'}, 'component 3': {'Component': '3', 'Name': '1-allyl-3-methylimidazolium chloride', 'Formula': 'C7H11ClN2', 'Mol weight': '158.63', 'SMILES': 
# ...

# %%
con.close
# Out:
# Collection(Database(MongoClient(host=['jifeng-shard-00-01.5dnvo.mongodb.net:27017', 'jifeng-shard-00-00.5dnvo.mongodb.net:27017', 'jifeng-shard-00-02.5dnvo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-5cetpl-shard-0', ssl=True), 'JiFeng'), 'ILD.close')

# %%
import sqlite3
import pandas as pd
import random
import numpy as np

# %%
conn = sqlite3.connect('example.db')

# %%
c = conn.cursor()
#c.execute('''CREATE TABLE stocks
#(date text, trans text, symbol text, qty real, price real)''')

# %%
c.execute("INSERT INTO stocks VALUES ('2006-01-05','BUY','RHAT',100,35.14)")
conn.commit()
conn.close()

# %%
df = pd.DataFrame(np.random.rand(9).reshape((3,3)))

# %%
df.to_sql('light', conn, if_exists='replace', index=True)
# Out:
# 3

# %%
df1 = pd.DataFrame.from_dict(df)

# %%
df1
# Out:
#      Temperature, K  Pressure, kPa  Speed of sound, m/s\nLiquid  Error  \
# 0            278.15        101.325                       1752.4    2.2
# 1            278.40        101.325                       1751.6    2.2
# 2            278.65        101.325                       1750.7    2.2
# 3            278.90        101.325                       1749.8    2.2
# 4            279.15        101.325                       1749.0    2.2
# ..              ...            ...                          ...    ...
# 236          337.16        101.325                       1573.7    2.1
# 237          337.40        101.325                       1572.9    2.1
# 238          337.66        101.325                       1572.1    2.1
# 239          337.90        101.325                       1571.3    2.1
# 240          338.15        101.325                       1570.6    2.1
#
#                           _id
# 0    62964f67aa9e4075e4a637e1
# 1    62964f67aa9e4075e4a637e2
# ...
